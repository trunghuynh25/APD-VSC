# %% [markdown]
# For DYNAMIC Peak count and depolarization start times

# %% [markdown]
# version 6b changelist:
# - Per ROI instead of global median ROI
# - Added troubleshooting functionalities (grey in plot is detected but filtered out of data table)
# #
# TO DO:
# - Add summary page with means and standard deviation for each ROI on 1st sheet, keeping the other two sheets
# - Possible correction for stimulation rate?
# - Flagging? i.e. 1Hz cannot have APD90 of >1000ms, etc
# - Alternans flagging (duration alternans)
# - DAD and EAD flagging
# - Fix occasional drifts
# - Fix low amplitude peak detection, occasional
# - Maybe start_idx (depolarization start) needs better detection settings?
# QUESTIONS?: huynh.trung@mayo.edu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from scipy.ndimage import gaussian_filter1d
from itertools import groupby
from operator import itemgetter

# === Config ===
excel_path = r"C:\Users\m254292\Downloads\Wei Book5.xlsx"
band_factor     = 1.5
upstroke_min    = 0.06

APPLY_FILTERS        = True    # toggle filters
GREY_OUT_UNFILTERED  = True    # grey removed events on plots

xls = pd.ExcelFile(excel_path)

def analyze_roi_signal(time, signal, sample_name, roi_label,
                       apply_filters=True,
                       grey_out_unfiltered=True):
    # --- Prep ---
    signal = pd.to_numeric(signal, errors='coerce').dropna().values
    time   = time[: len(signal)]

    Fmin       = np.min(signal)
    normalized = (signal - Fmin) / Fmin
    smoothed   = gaussian_filter1d(normalized, sigma=1)

    slope_initial = np.gradient(smoothed, time)

    # Photobleaching correction
    flat_thresh = np.percentile(np.abs(slope_initial), 20)
    flat_idxs   = np.where(np.abs(slope_initial) < flat_thresh)[0]
    if flat_idxs.size >= 2:
        bleach_curve = np.interp(time, time[flat_idxs], smoothed[flat_idxs])
        bleach_curve[bleach_curve == 0] = 1
        smoothed = smoothed / bleach_curve

    # Thresholds
    s_max, s_med = np.max(smoothed), np.median(smoothed)
    dr            = s_max - s_med
    rising_thresh = 0.05 * dr
    depol_thresh  = 0.02 * dr

    slope = np.gradient(smoothed, time)

    # Rising-edge groups
    edges  = np.where(slope > rising_thresh)[0]
    groups = []
    for k, g in groupby(enumerate(edges), lambda x: x[0] - x[1]):
        grp = [i for _, i in g]
        if len(grp) >= 5:
            groups.append(grp)

    # Candidate peaks
    peeks = []
    for grp in groups:
        start = grp[0]
        end   = min(grp[-1] + 20, len(smoothed))
        peeks.append(np.argmax(smoothed[start:end]) + start)

    # De-dupe
    filt_peeks = []
    for p in peeks:
        if not filt_peeks or p - filt_peeks[-1] > 40:
            filt_peeks.append(p)

    # Metrics
    rows = []
    for pk in filt_peeks:
        window = range(max(0, pk - 100), pk)
        cand   = [i for i in window if slope[i] < depol_thresh]
        if not cand:
            continue
        start_idx = cand[-1]

        pre       = smoothed[max(0, start_idx - 50): start_idx]
        baseline  = np.min(pre)
        peak_val  = smoothed[pk]
        amp       = peak_val - baseline

        # APD90
        lvl90 = baseline + 0.1 * amp
        repol90_idx = next((i for i in range(pk + 1, len(smoothed)) if smoothed[i] <= lvl90), None)
        if repol90_idx is None:
            continue
        repol90_time  = time[repol90_idx]
        repol90_level = smoothed[repol90_idx]
        apd90         = repol90_time - time[start_idx]

        # APD50
        lvl50 = baseline + 0.5 * amp
        repol50_idx = next((i for i in range(pk + 1, len(smoothed)) if smoothed[i] <= lvl50), None)
        if repol50_idx is None:
            continue
        apd50 = time[repol50_idx] - time[start_idx]

        ratio50_90 = apd50 / apd90 if apd90 > 0 else np.nan
        upstroke   = time[pk] - time[start_idx]

        rows.append({
            'Depolarization_Start_Time_s': time[start_idx],
            'Peak_Time_s'                : time[pk],
            'Amplitude'                  : amp,
            'APD50_s'                    : apd50,
            'APD90_s'                    : apd90,
            'APD50_90_Ratio'             : ratio50_90,
            'Upstroke_Time_s'            : upstroke,
            'Repolarization_Time_s'      : repol90_time,
            'Repolarization_Level'       : repol90_level
        })

    # DataFrame
    df_res_raw = pd.DataFrame(rows).reset_index().rename(columns={'index': '_orig'})
    df_res     = df_res_raw.copy()

    # --- Filters ---
    if apply_filters and not df_res.empty:
        # Upstroke filter
        df_res = df_res[df_res['Upstroke_Time_s'] > upstroke_min]

        # Symmetric APD90 trim
        median_apd90 = df_res['APD90_s'].median()
        lower = median_apd90 / band_factor
        upper = median_apd90 * band_factor
        df_res = df_res[(df_res['APD90_s'] >= lower) & (df_res['APD90_s'] <= upper)]

        df_res = df_res.reset_index(drop=True)

    # Figure out which events were removed (only for plotting, not for summary printing)
    removed = (df_res_raw[~df_res_raw['_orig'].isin(df_res['_orig'])] 
               if apply_filters and grey_out_unfiltered else
               pd.DataFrame(columns=df_res_raw.columns))

    expected = [
        'Depolarization_Start_Time_s', 'Peak_Time_s', 'Amplitude',
        'APD50_s', 'APD90_s', 'APD50_90_Ratio', 'Upstroke_Time_s',
        'Repolarization_Time_s', 'Repolarization_Level'
    ]
    df_res = df_res.reindex(columns=['_orig'] + expected)

    # --- Plot ---
    fig, ax = plt.subplots(figsize=(12, 5))
    ax.plot(time, smoothed, label='Signal')

    # Grey-out removed (if desired)
    if grey_out_unfiltered and not removed.empty:
        for i, t in enumerate(removed['Peak_Time_s']):
            ax.axvline(t, color='grey', linestyle='--', alpha=0.3,
                       label='Removed Peak' if i == 0 else None)
        for i, t in enumerate(removed['Depolarization_Start_Time_s']):
            ax.axvline(t, color='grey', linestyle=':', alpha=0.3,
                       label='Removed Depol Start' if i == 0 else None)
        for i, row in enumerate(removed.itertuples()):
            ax.hlines(y=row.Repolarization_Level,
                      xmin=row.Depolarization_Start_Time_s,
                      xmax=row.Repolarization_Time_s,
                      color='grey', linestyle='-', linewidth=2, alpha=0.3,
                      label='Removed APD90' if i == 0 else None)

    # Kept events
    for i, t in enumerate(df_res['Peak_Time_s']):
        ax.axvline(t, color='green', linestyle='--', alpha=0.8,
                   label='Peak' if i == 0 else None)
    for i, t in enumerate(df_res['Depolarization_Start_Time_s']):
        ax.axvline(t, color='black', linestyle='--', alpha=0.5,
                   label='Depol Start' if i == 0 else None)
    for i, row in enumerate(df_res.itertuples()):
        ax.hlines(y=row.Repolarization_Level,
                  xmin=row.Depolarization_Start_Time_s,
                  xmax=row.Repolarization_Time_s,
                  color='red', linestyle='-', linewidth=2, alpha=0.8,
                  label='APD90' if i == 0 else None)

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys())
    ax.set_xlabel("Time (s)")
    ax.set_ylabel("ΔF/Fmin")
    ax.set_title(f"{sample_name} | {roi_label} (bleach-corrected)")
    ax.grid(True)
    fig.tight_layout()

    return sample_name, roi_label, df_res, fig   # <- only filtered df returned


# === Main ===
all_results = []
plots       = []

for sheet_name in xls.sheet_names:
    raw = xls.parse(sheet_name, header=None, nrows=1)
    if raw.dropna(how='all').empty:
        continue
    sample_name = str(raw.iloc[0, 0])
    if sample_name.lower().endswith('.nd2'):
        sample_name = sample_name[:-4]

    df = xls.parse(sheet_name, header=1)
    if df.dropna(how='all').empty:
        continue
    df.columns = df.columns.astype(str).str.strip()

    time_cols = [c for c in df.columns if 'time' in c.lower()]
    if not time_cols:
        continue
    time = pd.to_numeric(df[time_cols[0]], errors='coerce').values

    roi_cols = [c for c in df.columns if c != time_cols[0] and 'Mono' in c]
    for roi in roi_cols:
        samp, roi_label, res_df, fig = analyze_roi_signal(
            time, df[roi], sample_name, roi,
            apply_filters=APPLY_FILTERS,
            grey_out_unfiltered=GREY_OUT_UNFILTERED
        )

        res_df.insert(0, 'Sample', samp)
        res_df.insert(1, 'ROI', roi_label)

        all_results.append(res_df)
        plots.append((samp, roi_label, fig))

# === Only filtered summary ===
if all_results:
    summary_df = pd.concat(all_results, ignore_index=True)
    print("Filtered summary:")
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(summary_df)
# Out:
# C:\Users\m254292\AppData\Local\Temp\ipykernel_20536\4222943473.py:144: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(12, 5))
# Filtered summary:
#                                    Sample               ROI  _orig  \
# 0     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      0
# 1     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      1
# 2     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      2
# 3     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      3
# 4     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      4
# 5     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      5
# 6     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      6
# 7     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      7
# 8     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      8
# 9     63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)      9
# 10    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     10
# 11    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     11
# 12    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     12
# 13    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     13
# 14    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     14
# 15    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     15
# 16    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     16
# 17    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     17
# 18    63C42-DF_6-21-D38-No treatment-0001   #1 (Mono - GFP)     18
# 19    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      0
# 20    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      1
# 21    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      2
# 22    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      3
# 23    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      4
# 24    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      5
# 25    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      6
# 26    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      7
# 27    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      8
# 28    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)      9
# 29    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     10
# 30    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     11
# 31    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     12
# 32    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     13
# 33    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     14
# 34    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     15
# 35    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     16
# 36    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     17
# 37    63C42-DF_6-21-D38-No treatment-0001   #2 (Mono - GFP)     18
# 38    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      0
# 39    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      1
# 40    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      2
# 41    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      3
# 42    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      4
# 43    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      5
# 44    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      6
# 45    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      7
# 46    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      8
# 47    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)      9
# 48    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     10
# 49    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     11
# 50    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     12
# 51    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     13
# 52    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     14
# 53    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     15
# 54    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     16
# 55    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     17
# 56    63C42-DF_6-21-D38-No treatment-0001   #3 (Mono - GFP)     18
# 57    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      0
# 58    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      1
# 59    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      2
# 60    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      3
# 61    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      4
# 62    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      5
# 63    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      6
# 64    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      7
# 65    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      8
# 66    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)      9
# 67    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     10
# 68    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     11
# 69    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     12
# 70    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     13
# 71    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     14
# 72    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     15
# 73    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     16
# 74    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     17
# 75    63C42-DF_6-21-D38-No treatment-0001   #4 (Mono - GFP)     18
# 76    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      0
# 77    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      1
# 78    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      2
# 79    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      3
# 80    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      4
# 81    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      5
# 82    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      6
# 83    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      7
# 84    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      8
# 85    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)      9
# 86    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     10
# 87    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     11
# 88    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     12
# 89    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     13
# 90    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     14
# 91    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     15
# 92    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     16
# 93    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     17
# 94    63C42-DF_6-21-D38-No treatment-0001   #5 (Mono - GFP)     18
# 95    63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      0
# 96    63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      1
# 97    63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      2
# 98    63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      4
# 99    63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      5
# 100   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      6
# 101   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      8
# 102   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)      9
# 103   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     10
# 104   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     11
# 105   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     12
# 106   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     13
# 107   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     14
# 108   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     15
# 109   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     16
# 110   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     17
# 111   63C42-DF_6-21-D38-No treatment-0001   #6 (Mono - GFP)     18
# 112   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      0
# 113   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      1
# 114   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      2
# 115   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      3
# 116   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      4
# 117   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      5
# 118   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      6
# 119   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      7
# 120   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      8
# 121   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)      9
# 122   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     10
# 123   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     11
# 124   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     12
# 125   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     13
# 126   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     14
# 127   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     15
# 128   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     16
# 129   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     17
# 130   63C42-DF_6-21-D38-No treatment-0001   #7 (Mono - GFP)     18
# 131   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      0
# 132   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      1
# 133   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      2
# 134   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      3
# 135   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      4
# 136   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      5
# 137   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      6
# 138   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      7
# 139   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      8
# 140   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)      9
# 141   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     10
# 142   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     11
# 143   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     12
# 144   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     13
# 145   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     14
# 146   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     15
# 147   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     16
# 148   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     17
# 149   63C42-DF_6-21-D38-No treatment-0001   #8 (Mono - GFP)     18
# 150   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      0
# 151   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      1
# 152   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      2
# 153   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      3
# 154   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      4
# 155   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      5
# 156   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      6
# 157   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      7
# 158   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      8
# 159   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)      9
# 160   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     10
# 161   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     11
# 162   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     12
# 163   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     13
# 164   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     14
# 165   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     15
# 166   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     16
# 167   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     17
# 168   63C42-DF_6-21-D38-No treatment-0001   #9 (Mono - GFP)     18
# 169   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      0
# 170   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      1
# 171   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      2
# 172   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      3
# 173   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      4
# 174   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      5
# 175   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      6
# 176   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      7
# 177   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      8
# 178   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)      9
# 179   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     10
# 180   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     11
# 181   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     12
# 182   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     13
# 183   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     14
# 184   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     15
# 185   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     16
# 186   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     17
# 187   63C42-DF_6-21-D38-No treatment-0001  #10 (Mono - GFP)     18
# 188   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      0
# 189   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      1
# 190   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      2
# 191   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      3
# 192   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      4
# 193   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      5
# 194   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      6
# 195   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      7
# 196   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      8
# 197   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)      9
# 198   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     10
# 199   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     11
# 200   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     12
# 201   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     13
# 202   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     14
# 203   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     15
# 204   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     16
# 205   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     17
# 206   63C42-DF_6-21-D38-No treatment-0001  #11 (Mono - GFP)     18
# 207   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      0
# 208   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      1
# 209   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      2
# 210   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      3
# 211   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      4
# 212   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      5
# 213   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      6
# 214   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      7
# 215   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      8
# 216   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)      9
# 217   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     10
# 218   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     11
# 219   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     12
# 220   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     13
# 221   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     14
# 222   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     15
# 223   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     16
# 224   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     17
# 225   63C42-DF_6-21-D38-No treatment-0001  #12 (Mono - GFP)     18
# 226   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      0
# 227   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      1
# 228   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      2
# 229   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      3
# 230   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      4
# 231   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      5
# 232   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      6
# 233   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      7
# 234   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      8
# 235   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)      9
# 236   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     10
# 237   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     11
# 238   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     12
# 239   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     13
# 240   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     14
# 241   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     15
# 242   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     16
# 243   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     17
# 244   63C42-DF_6-21-D38-No treatment-0001  #13 (Mono - GFP)     18
# 245   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      0
# 246   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      1
# 247   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      2
# 248   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      3
# 249   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      4
# 250   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      5
# 251   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      6
# 252   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      7
# 253   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      8
# 254   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)      9
# 255   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     10
# 256   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     11
# 257   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     12
# 258   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     13
# 259   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     14
# 260   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     15
# 261   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     16
# 262   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     17
# 263   63C42-DF_6-21-D38-No treatment-0001  #14 (Mono - GFP)     18
# 264   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      0
# 265   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      1
# 266   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      2
# 267   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      3
# 268   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      4
# 269   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      5
# 270   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      6
# 271   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      7
# 272   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      8
# 273   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)      9
# 274   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     10
# 275   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     11
# 276   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     12
# 277   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     13
# 278   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     14
# 279   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     15
# 280   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     16
# 281   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     17
# 282   63C42-DF_6-21-D38-No treatment-0001  #15 (Mono - GFP)     18
# 283   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      0
# 284   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      1
# 285   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      2
# 286   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      3
# 287   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      4
# 288   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      5
# 289   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      6
# 290   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      7
# 291   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      8
# 292   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)      9
# 293   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     10
# 294   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     11
# 295   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     12
# 296   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     13
# 297   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     14
# 298   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     15
# 299   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     16
# 300   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     17
# 301   63C42-DF_6-21-D38-No treatment-0001  #16 (Mono - GFP)     18
# 302   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      0
# 303   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      1
# 304   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      2
# 305   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      3
# 306   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      4
# 307   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      5
# 308   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      6
# 309   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      7
# 310   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      8
# 311   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)      9
# 312   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     10
# 313   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     11
# 314   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     12
# 315   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     13
# 316   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     14
# 317   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     15
# 318   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     16
# 319   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     17
# 320   63C42-DF_6-21-D38-No treatment-0001  #17 (Mono - GFP)     18
# 321   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      0
# 322   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      1
# 323   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      2
# 324   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      3
# 325   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      4
# 326   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      5
# 327   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      6
# 328   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      7
# 329   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      8
# 330   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)      9
# 331   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     10
# 332   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     11
# 333   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     12
# 334   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     13
# 335   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     14
# 336   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     15
# 337   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     16
# 338   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     17
# 339   63C42-DF_6-21-D38-No treatment-0001  #18 (Mono - GFP)     18
# 340   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      0
# 341   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      1
# 342   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      2
# 343   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      3
# 344   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      4
# 345   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      5
# 346   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      7
# 347   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      8
# 348   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)      9
# 349   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     10
# 350   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     11
# 351   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     12
# 352   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     13
# 353   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     14
# 354   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     15
# 355   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     16
# 356   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     17
# 357   63C42-DF_6-21-D38-No treatment-0001  #19 (Mono - GFP)     18
# 358   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      0
# 359   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      1
# 360   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      2
# 361   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      3
# 362   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      4
# 363   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      5
# 364   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      6
# 365   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      7
# 366   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      8
# 367   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)      9
# 368   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     10
# 369   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     11
# 370   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     12
# 371   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     13
# 372   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     14
# 373   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     15
# 374   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     16
# 375   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     17
# 376   63C42-DF_6-21-D38-No treatment-0001  #20 (Mono - GFP)     18
# 377   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      0
# 378   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      1
# 379   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      2
# 380   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      3
# 381   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      4
# 382   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      5
# 383   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      6
# 384   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      7
# 385   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      8
# 386   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)      9
# 387   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     10
# 388   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     11
# 389   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     12
# 390   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     13
# 391   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     14
# 392   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     15
# 393   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     16
# 394   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     17
# 395   63C42-DF_6-21-D38-No treatment-0002   #1 (Mono - GFP)     18
# 396   63C42-DF_6-21-D38-No treatment-0002   #2 (Mono - GFP)     11
# 397   63C42-DF_6-21-D38-No treatment-0002   #2 (Mono - GFP)     13
# 398   63C42-DF_6-21-D38-No treatment-0002   #2 (Mono - GFP)     15
# 399   63C42-DF_6-21-D38-No treatment-0002   #2 (Mono - GFP)     17
# 400   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      0
# 401   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      1
# 402   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      2
# 403   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      3
# 404   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      4
# 405   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      5
# 406   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      6
# 407   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      7
# 408   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      8
# 409   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)      9
# 410   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     10
# 411   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     11
# 412   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     12
# 413   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     13
# 414   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     14
# 415   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     15
# 416   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     16
# 417   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     17
# 418   63C42-DF_6-21-D38-No treatment-0002   #3 (Mono - GFP)     18
# 419   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      0
# 420   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      1
# 421   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      2
# 422   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      3
# 423   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      4
# 424   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      5
# 425   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      6
# 426   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      7
# 427   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      8
# 428   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)      9
# 429   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     10
# 430   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     11
# 431   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     12
# 432   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     13
# 433   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     14
# 434   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     15
# 435   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     16
# 436   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     17
# 437   63C42-DF_6-21-D38-No treatment-0002   #4 (Mono - GFP)     18
# 438   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      0
# 439   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      1
# 440   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      2
# 441   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      3
# 442   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      4
# 443   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      5
# 444   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      6
# 445   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      7
# 446   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      8
# 447   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)      9
# 448   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     10
# 449   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     11
# 450   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     12
# 451   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     13
# 452   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     14
# 453   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     15
# 454   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     16
# 455   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     17
# 456   63C42-DF_6-21-D38-No treatment-0002   #5 (Mono - GFP)     18
# 457   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      0
# 458   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      1
# 459   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      2
# 460   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      3
# 461   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      4
# 462   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      5
# 463   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      6
# 464   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      7
# 465   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      8
# 466   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)      9
# 467   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     10
# 468   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     11
# 469   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     12
# 470   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     13
# 471   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     14
# 472   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     15
# 473   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     16
# 474   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     17
# 475   63C42-DF_6-21-D38-No treatment-0002   #6 (Mono - GFP)     18
# 476   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      0
# 477   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      1
# 478   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      2
# 479   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      3
# 480   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      4
# 481   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      5
# 482   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      6
# 483   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      7
# 484   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      8
# 485   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)      9
# 486   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     10
# 487   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     11
# 488   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     12
# 489   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     13
# 490   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     14
# 491   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     15
# 492   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     16
# 493   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     17
# 494   63C42-DF_6-21-D38-No treatment-0002   #7 (Mono - GFP)     18
# 495   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      0
# 496   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      1
# 497   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      2
# 498   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      3
# 499   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      4
# 500   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      5
# 501   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      6
# 502   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      7
# 503   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      8
# 504   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)      9
# 505   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     10
# 506   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     11
# 507   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     12
# 508   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     13
# 509   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     14
# 510   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     15
# 511   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     16
# 512   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     17
# 513   63C42-DF_6-21-D38-No treatment-0002   #8 (Mono - GFP)     18
# 514   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      0
# 515   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      1
# 516   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      2
# 517   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      3
# 518   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      4
# 519   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      5
# 520   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      6
# 521   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      7
# 522   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      8
# 523   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)      9
# 524   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     10
# 525   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     11
# 526   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     12
# 527   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     13
# 528   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     14
# 529   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     15
# 530   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     16
# 531   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     17
# 532   63C42-DF_6-21-D38-No treatment-0002   #9 (Mono - GFP)     18
# 533   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      0
# 534   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      1
# 535   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      2
# 536   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      3
# 537   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      4
# 538   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      5
# 539   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      6
# 540   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      7
# 541   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      8
# 542   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)      9
# 543   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     10
# 544   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     11
# 545   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     12
# 546   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     13
# 547   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     14
# 548   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     15
# 549   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     16
# 550   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     17
# 551   63C42-DF_6-21-D38-No treatment-0002  #10 (Mono - GFP)     18
# 552   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      0
# 553   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      1
# 554   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      2
# 555   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      3
# 556   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      4
# 557   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      5
# 558   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      6
# 559   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      7
# 560   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      8
# 561   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)      9
# 562   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     10
# 563   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     11
# 564   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     12
# 565   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     13
# 566   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     14
# 567   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     15
# 568   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     16
# 569   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     17
# 570   63C42-DF_6-21-D38-No treatment-0002  #11 (Mono - GFP)     18
# 571   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      0
# 572   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      1
# 573   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      2
# 574   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      3
# 575   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      4
# 576   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      5
# 577   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      6
# 578   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      7
# 579   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      8
# 580   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)      9
# 581   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     10
# 582   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     11
# 583   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     12
# 584   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     13
# 585   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     14
# 586   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     15
# 587   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     16
# 588   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     17
# 589   63C42-DF_6-21-D38-No treatment-0002  #12 (Mono - GFP)     18
# 590   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      0
# 591   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      1
# 592   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      2
# 593   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      5
# 594   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      6
# 595   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      7
# 596   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      8
# 597   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)      9
# 598   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     10
# 599   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     11
# 600   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     12
# 601   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     13
# 602   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     14
# 603   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     15
# 604   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     16
# 605   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     17
# 606   63C42-DF_6-21-D38-No treatment-0002  #13 (Mono - GFP)     18
# 607   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      0
# 608   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      1
# 609   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      2
# 610   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      3
# 611   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      4
# 612   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      5
# 613   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      6
# 614   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      7
# 615   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      8
# 616   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)      9
# 617   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     10
# 618   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     11
# 619   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     12
# 620   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     13
# 621   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     14
# 622   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     15
# 623   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     16
# 624   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     17
# 625   63C42-DF_6-21-D38-No treatment-0002  #14 (Mono - GFP)     18
# 626   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      0
# 627   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      1
# 628   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      2
# 629   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      3
# 630   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      4
# 631   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      5
# 632   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      6
# 633   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      7
# 634   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      8
# 635   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)      9
# 636   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     10
# 637   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     11
# 638   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     12
# 639   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     13
# 640   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     14
# 641   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     15
# 642   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     16
# 643   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     17
# 644   63C42-DF_6-21-D38-No treatment-0002  #15 (Mono - GFP)     18
# 645   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      0
# 646   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      1
# 647   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      2
# 648   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      3
# 649   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      4
# 650   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      5
# 651   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      6
# 652   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      7
# 653   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      8
# 654   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)      9
# 655   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     10
# 656   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     11
# 657   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     12
# 658   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     13
# 659   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     14
# 660   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     15
# 661   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     16
# 662   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     17
# 663   63C42-DF_6-21-D38-No treatment-0002  #16 (Mono - GFP)     18
# 664   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      0
# 665   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      1
# 666   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      2
# 667   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      3
# 668   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      4
# 669   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      5
# 670   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      6
# 671   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      7
# 672   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      8
# 673   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)      9
# 674   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)     10
# 675   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)     11
# 676   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)     12
# 677   63C42-DF_6-21-D38-No treatment-0002  #17 (Mono - GFP)     13
# ...
# 1662              0.022886
# 1663              0.023875
# 1664              0.023333
# 1665              0.023915
# 1666              0.022410
# 1667              0.022453
# 1668              0.022924
# 1669              0.022652
# 1670              0.021677
# 1671              0.022240
# 1672              0.023547
# 1673              0.021953
# 1674              0.022964
# 1675              0.023478
# 1676              0.022876
# 1677              0.022704
# 1678              0.024799
# 1679              0.019945
# 1680              0.019709
# 2145              0.023938
# 2146              0.022111
# 2147              0.024598
# 2148              0.022736
# 2149              0.023522
# 2150              0.025099
# 2151              0.023733
# 2152              0.023847
# 2153              0.024670
# 2154              0.025329
# 2155              0.023877
# 2156              0.022500
# 2157              0.023611
# 2158              0.025924
# 2159              0.025372
# 2160              0.026150
# 2161              0.024250
# 2162              0.029073
# 2163              0.025493
# 2164              0.028636
# 2165              0.027827
# 2166              0.028513
# 2167              0.030227
# 2168              0.029341
# 2169              0.029727
# 2170              0.029318
# 2171              0.027692
# 2172              0.029338
# 2173              0.029879
# 2174              0.026468
# 2175              0.019498
# 2176              0.020145
# 2177              0.019164
# 2178              0.020482
# 2179              0.019246
# 2180              0.020116
# 2181              0.019928
# 2182              0.018888
# 2183              0.019738
# 2184              0.020471
# 2185              0.020706
# 2186              0.020985
# 2187              0.020996
# 2188              0.020821
# 2189              0.020782
# 2190              0.022286
# 2191              0.023241
# 2192              0.021748
# 2193              0.022557
# 2194              0.022637
# 2195              0.024182
# 2196              0.022133
# 2197              0.025716
# 2198              0.024213
# 2199              0.025298
# 2200              0.026043
# 2201              0.026725
# 2202              0.028395
# 2203              0.026991
# 2204              0.027468
# 2205              0.028150
# 2206              0.027967
# 2207              0.029032
# 2208              0.030098
# 2209              0.029163
# 2210              0.028390
# 2211              0.029765
# 2212              0.029291

# %%
import os
import io

# === After you’ve built `all_results` and `summary_df` ===
# (and assuming you modified analyze_roi_signal to return the Figure object:)
#
# e.g. def analyze_roi_signal(...):
#       …
#       fig, ax = plt.subplots(figsize=(12,5))
#       ax.plot(...)
#       … 
#       return sample_name, roi_label, df_res, fig
#
# And in your loop you collected:
#    plots = []  # list of (sample, roi, fig)
#    for …:
#        samp, roi, df_res, fig = analyze_roi_signal(...)
#        plots.append((samp, roi, fig))
#        # insert sample/ROI into df_res as before
#        all_results.append(df_res)
#
# At this point you have:
#    summary_df  ← pd.concat(all_results)
#    plots       ← list of (sample, roi, fig)

# === Dynamically build out_path using os.path (Option 1) ===
folder, basename = os.path.split(excel_path)
name, ext       = os.path.splitext(basename)
new_name        = f"{name} batch analysis{ext}"
out_path        = os.path.join(folder, new_name)

# === Write summary_df and plots into the new workbook ===
with pd.ExcelWriter(out_path, engine='xlsxwriter') as writer:
    # 1) summary table
    summary_df.to_excel(writer, sheet_name='Summary', index=False)

    # 2) embed plots
    workbook  = writer.book
    worksheet = workbook.add_worksheet('Plots')

    img_row = 0
    for sample, roi, fig in plots:
        buf = io.BytesIO()
        fig.savefig(buf, format='png', dpi=150, bbox_inches='tight')
        buf.seek(0)

        worksheet.write(img_row, 0, f"{sample} | {roi}")
        img_row += 1

        worksheet.insert_image(
            img_row, 0,
            f"{sample}_{roi}.png",
            {'image_data': buf, 'x_scale': 0.8, 'y_scale': 0.8}
        )
        img_row += 30

print(f"✅ Saved batch analysis to:\n  {out_path}")
# Out:
# ✅ Saved batch analysis to:
#   C:\Users\m254292\Downloads\Wei Book2 batch analysis.xlsx

# %% [markdown]
# To Do:
# - Add APD50
# - Add ratio of APD50/90
